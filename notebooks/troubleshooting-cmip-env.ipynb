# %%
# conda environments on bash
# !conda env list
# Out:
# # conda environments:
# #
#                          /glade/work/kdagon/miniconda
#                          /glade/work/kdagon/miniconda/envs/ML
#                          /glade/work/kdagon/miniconda/envs/MLgpu
#                          /glade/work/kdagon/miniconda/envs/analysis
#                          /glade/work/kdagon/miniconda/envs/cmip6
#                          /glade/work/kdagon/miniconda/envs/ctsm-py
#                          /glade/work/kdagon/miniconda/envs/python-tutorial
# base                  *  /ncar/usr/jupyterhub/20190905

# %%
# !which python
# Out:
# /ncar/usr/jupyterhub/20190905/bin/python

# %%
import intake
intake.__file__
# Out:
# '/glade/work/kdagon/miniconda/envs/cmip6/lib/python3.7/site-packages/intake/__init__.py'

# %%
# conda environments in current python kernel (cmip6), different from bash command
conda env list
# Out:
#   File "<ipython-input-3-b92416faa3f1>", line 2
#     conda env list
#             ^
# SyntaxError: invalid syntax

# %%
conda list
# Out:
# # packages in environment at /ncar/usr/jupyterhub/envs/cmip6-201910a:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main    defaults
# absl-py                   0.8.1                    py37_0    conda-forge
# affine                    2.3.0                      py_0    conda-forge
# aiohttp                   3.6.1            py37h516909a_0    conda-forge
# altair                    3.2.0                    py37_0    conda-forge
# antlr-python-runtime      4.7.2                 py37_1000    conda-forge
# appdirs                   1.4.3                      py_1    conda-forge
# arrow-cpp                 0.15.0           py37h5ac5442_0    conda-forge
# asciitree                 0.3.3                      py_2    conda-forge
# asn1crypto                1.2.0                    py37_0    conda-forge
# astor                     0.7.1                      py_0    conda-forge
# ...

# %%
# different from the above
# !conda list
# Out:
# # packages in environment at /ncar/usr/jupyterhub/20190905:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main    defaults
# aiohttp                   3.5.4            py37h14c3975_0    conda-forge
# alembic                   1.1.0                      py_0    conda-forge
# asn1crypto                0.24.0                   py37_0    defaults
# async-timeout             3.0.1                   py_1000    conda-forge
# async_generator           1.10                       py_0    conda-forge
# attrs                     19.1.0                     py_0    conda-forge
# backcall                  0.1.0                      py_0    conda-forge
# bleach                    3.1.0                      py_0    conda-forge
# blinker                   1.4                        py_1    conda-forge
# bokeh                     1.3.4                    py37_0    conda-forge
# ...

# %%
# export the current python kernel base environment (cmip6)
conda env export --name base > environment.yml
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   analysis             /glade/u/home/kdagon/.local/share/jupyter/kernels/analysis
#   cmip6                /glade/u/home/kdagon/.local/share/jupyter/kernels/cmip6
#   ctsm-py              /glade/u/home/kdagon/.local/share/jupyter/kernels/ctsm-py
#   ml                   /glade/u/home/kdagon/.local/share/jupyter/kernels/ml
#   mlgpu                /glade/u/home/kdagon/.local/share/jupyter/kernels/mlgpu
#   npc_20190627_chy     /glade/u/home/kdagon/.local/share/jupyter/kernels/npc_20190627_chy
#   npc_20190723_csp     /glade/u/home/kdagon/.local/share/jupyter/kernels/npc_20190723_csp
#   bash                 /ncar/usr/jupyterhub/20190905/share/jupyter/kernels/bash
#   cmip6-201910         /ncar/usr/jupyterhub/20190905/share/jupyter/kernels/cmip6-201910
#   cmip6-201910a        /ncar/usr/jupyterhub/20190905/share/jupyter/kernels/cmip6-201910a
#   ir351                /ncar/usr/jupyterhub/20190905/share/jupyter/kernels/ir351
# ...

# %%
conda info
# Out:
#      active environment : None
#        user config file : /glade/u/home/kdagon/.condarc
#  populated config files : /glade/u/home/kdagon/.condarc
#           conda version : 4.7.12
#     conda-build version : not installed
#          python version : 3.7.3.final.0
#        virtual packages :
#        base environment : /ncar/usr/jupyterhub/20190905  (read only)
#            channel URLs : https://conda.anaconda.org/conda-forge/linux-64
#                           https://conda.anaconda.org/conda-forge/noarch
#                           https://repo.anaconda.com/pkgs/main/linux-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/linux-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /ncar/usr/jupyterhub/20190905/pkgs
#                           /glade/u/home/kdagon/.conda/pkgs
#        envs directories : /glade/u/home/kdagon/.conda/envs
# ...

# %%
# !conda info
# Out:
#      active environment : None
#        user config file : /glade/u/home/kdagon/.condarc
#  populated config files : /glade/u/home/kdagon/.condarc
#           conda version : 4.7.12
#     conda-build version : not installed
#          python version : 3.7.3.final.0
#        virtual packages :
#        base environment : /ncar/usr/jupyterhub/20190905  (read only)
#            channel URLs : https://conda.anaconda.org/conda-forge/linux-64
#                           https://conda.anaconda.org/conda-forge/noarch
#                           https://repo.anaconda.com/pkgs/main/linux-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/linux-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /ncar/usr/jupyterhub/20190905/pkgs
#                           /glade/u/home/kdagon/.conda/pkgs
#        envs directories : /glade/u/home/kdagon/.conda/envs
# ...

# %%
conda env list
# Out:
# # conda environments:
# #
#                          /glade/work/kdagon/miniconda
#                          /glade/work/kdagon/miniconda/envs/ML
#                          /glade/work/kdagon/miniconda/envs/MLgpu
#                          /glade/work/kdagon/miniconda/envs/analysis
#                          /glade/work/kdagon/miniconda/envs/cmip6
#                          /glade/work/kdagon/miniconda/envs/ctsm-py
#                          /glade/work/kdagon/miniconda/envs/python-tutorial
# base                  *  /ncar/usr/jupyterhub/20190905
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !conda activate cmip6-201910a
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
